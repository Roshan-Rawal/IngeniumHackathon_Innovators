# %%
from textblob import TextBlob
from textblob.classifiers import NaiveBayesClassifier
import pandas as pd

# %%
with open("pt.csv","r") as fp:
    c1 = NaiveBayesClassifier(fp)

# %%
c1
# Out:
# <NaiveBayesClassifier trained on 14 instances>

# %%
#a = input("Enter your answer")
print(c1.classify("I prefer to talk friends/family"))
# Out:
# Ex

# %% [markdown]
# ## With MBTI dataset

# %%
import pandas as pd

data = pd.read_csv("mbti_1.csv")
data
#data1 = data['type','posts']
#c2 = NaiveBayesClassifier(data)
# Out:
#                                                   posts  type
# 0     'http://www.youtube.com/watch?v=qsXHcwe3krw|||...  INFJ
# 1     'I'm finding the lack of me in these posts ver...  ENTP
# 2     'Good one  _____   https://www.youtube.com/wat...  INTP
# 3     'Dear INTP,   I enjoyed our conversation the o...  INTJ
# 4     'You're fired.|||That's another silly misconce...  ENTJ
# 5     '18/37 @.@|||Science  is not perfect. No scien...  INTJ
# 6     'No, I can't draw on my own nails (haha). Thos...  INFJ
# 7     'I tend to build up a collection of things on ...  INTJ
# 8     I'm not sure, that's a good question. The dist...  INFJ
# 9     'https://www.youtube.com/watch?v=w8-egj0y8Qs||...  INTP
# 10    'One time my parents were fighting over my dad...  INFJ
# 11    'https://www.youtube.com/watch?v=PLAaiKvHvZs||...  ENFJ
# 12    'Joe santagato - ENTP|||ENFJ or  ENTP?   I'm n...  INFJ
# 13    'Fair enough, if that's how you want to look a...  INTJ
# 14    'Basically this...  https://youtu.be/1pH5c1Jkh...  INTP
# 15    'Your comment screams INTJ, bro. Especially th...  INTP
# 16    'some of these both excite and calm me:  BUTTS...  INFJ
# 17    'I think we do agree. I personally don't consi...  INFP
# 18    'I fully believe in the power of being a prote...  INFJ
# 19    'That's normal, it happens also to me. If I am...  INFP
# 20    'Steve Job's was recognized for his striving f...  INTP
# 21    'It is very annoying to be misinterpreted. Esp...  INFJ
# 22    'Now I'm interested. But too lazy to go resear...  ENTJ
# 23    '45016 urh sorry uh. couldn't resist.|||all of...  INFP
# 24    'Still going strong at just over the two year ...  ENTJ
# 25    'Personally, I was thinking this would be more...  INFP
# 26    'He doesn't want to go on the trip without me,...  ENFP
# 27    'They paint without numbers|||I'd guess at ist...  ISFP
# 28    'Basically, my main questions are : What do yo...  INFP
# 29    'I think that that can absolutely be true of i...  INFJ
# ...                                                 ...   ...
# 8645  'I play cello, and I'm also a classically trai...  INFJ
# 8646  Its more or less based on how YOU experienced ...  INFP
# 8647  Socionics picked up on this.  They call it vis...  INTP
# 8648  'Good advice, thank you.|||I am in a tough sit...  INFP
# 8649  https://www.youtube.com/watch?v=nPDusM-75FE  e...  INFP
# 8650  'I think the real question is whether INFJs ca...  INFJ
# 8651  '-Being alone -Being insensitive  -Over thinki...  ISTP
# 8652  'Being assertive and standing up for myself is...  ISFJ
# 8653  'You should do whatever it is you want. If you...  INFP
# 8654  'Assuming I had a hand in it, I always at leas...  ISTJ
# 8655  'I find that poster and your facial expression...  INFJ
# 8656  Rim  In some approximate order, it seems like ...  INFJ
# 8657  Social  1) Generally, I positively associate w...  INTJ
# 8658  'Don't worry, I do that too when a car comes c...  ESFJ
# 8659  'leoni I had really bad social anxiety until I...  ENFP
# 8660  'I love the vastness of the sky, because my pr...  INFP
# 8661  '**haven't logged in and read posts for over 6...  ENTP
# 8662  'I can't say I have any one specific belief. I...  INTJ
# 8663  'doesn't matter, you don't have a choice, Elec...  INTP
# 8664  'https://www.youtube.com/watch?v=7zsMdi714mI||...  INTP
# 8665  'This test wasn't even close on my gender, age...  ENTP
# 8666  'Highly recommend this to those who wants to t...  INTJ
# 8667  'I think generally people experience post trau...  ENTP
# 8668  'Here's a planned stress relieving activity th...  INTJ
# 8669  'I'm not sure about a method for picking out I...  INFJ
# 8670  'https://www.youtube.com/watch?v=t8edHB_h908||...  ISFP
# 8671  'So...if this thread already exists someplace ...  ENFP
# 8672  'So many questions when i do these things.  I ...  INTP
# 8673  'I am very conflicted right now when it comes ...  INFP
# 8674  'It has been too long since I have been on per...  INFP
#
# [8675 rows x 2 columns]

# %%
with open("mbti_1.csv","r") as fp:
    c1 = NaiveBayesClassifier(fp)
